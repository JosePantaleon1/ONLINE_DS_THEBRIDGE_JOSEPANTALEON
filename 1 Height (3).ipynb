# %% [markdown]
# ### Se pide, usando regresión lineal:
#
# Dibujar con una línea la relación que hay entre la altura y la edad de los alumnos de esta clase:
#
# - ¿Es una buena técnica para este tipo de problemas? ¿Por qué?
# - ¿Qué error se comete? Calcula los errores que está cometiendo tu modelo uno a uno (lo tienes que calcular tú con python). Aparte, usa el MSE y el RMSE. ¿Alguno es mejor para este problema?
# - Representa la matriz de correlación, ¿los datos están correlacionados?

# %%
lista_alumnos = [("Caranchoa", 24, 1.82), 
                 ("Leo Messi", 25, 1.71), 
                 ("El bicho", 35, 1.66), 
                 ("Paquirrin", 37, 1.63), 
                 ("John Cobra", 29, 1.90), 
                 ("El tomate", 27, 1.80), 
                 ("El chucky de cieza", 28, 1.70), 
                 ("Chiquito de la Calzada", 32, 1.60), 
                 ("El cuñao", 36, 1.74), 
                 ("Rafa Nadal", 45, 1.72), 
                 ("Pau Gasol", 41, 1.65), 
                 ("El hermano de Pau Gasol", 30, 1.65), 
                 ("Joselito", 40, 1.60), 
                 ("Maria Isabel", 39, 1.80), 
                 ("Melody", 23, 1.77), 
                 ("Las ketchup", 32, 1.75), 
                 ("Pumuki", 27, 1.70), 
                 ("Naranjito", 34, 1.80), 
                 ("Espinete", 27, 1.77), 
                 ("El Feli", 28, 1.70), 
                 ("Jose Luis", 35, 1.80)]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Crea el siguiente DataFrame
df_alumnos = pd.DataFrame(lista_alumnos, columns=["Name", "Age", "Height"])
df_alumnos
# Out:
#                        Name  Age  Height
# 0                 Caranchoa   24    1.82
# 1                 Leo Messi   25    1.71
# 2                  El bicho   35    1.66
# 3                 Paquirrin   37    1.63
# 4                John Cobra   29    1.90
# 5                 El tomate   27    1.80
# 6        El chucky de cieza   28    1.70
# 7    Chiquito de la Calzada   32    1.60
# 8                  El cuñao   36    1.74
# 9                Rafa Nadal   45    1.72
# 10                Pau Gasol   41    1.65
# 11  El hermano de Pau Gasol   30    1.65
# 12                 Joselito   40    1.60
# 13             Maria Isabel   39    1.80
# 14                   Melody   23    1.77
# 15              Las ketchup   32    1.75
# 16                   Pumuki   27    1.70
# 17                Naranjito   34    1.80
# 18                 Espinete   27    1.77
# 19                  El Feli   28    1.70
# 20                Jose Luis   35    1.80

# %%
# Muestra la info
df_alumnos.info()# tipo de dato y ver si hay nulls, trabajamos con age and height
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    21 non-null     object
#  1   Age     21 non-null     int64
#  2   Height  21 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 636.0+ bytes

# %%
# Muestra los estadísticos del df
df_alumnos.describe()
# Out:
#              Age     Height
# count  21.000000  21.000000
# mean   32.095238   1.727143
# std     6.081980   0.079003
# min    23.000000   1.600000
# 25%    27.000000   1.660000
# 50%    32.000000   1.720000
# 75%    36.000000   1.800000
# max    45.000000   1.900000

# %%
# Genera un scatter plot con Edad y Altura

plt.scatter(df_alumnos['Age'], df_alumnos['Height'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Genera un heatmap
correlation_matrix = df_alumnos[['Age', 'Height']].corr()
sns.heatmap(correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
# Genera un distplot
sns.distplot(df_alumnos['Age']);
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13448\1117438708.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_alumnos['Age']);

# %%
# Divide el df en features (X) y target (y)

X = df_alumnos[['Age']]#bidimensionales
y= df_alumnos[['Height']]#unidimensional

# %%
from sklearn.model_selection import train_test_split


# Divide los datos en conjunto de entrenamiento y test
# Siendo el tamaño del conjunto test un 30% y la semilla sea 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)# el random es la forma q le aprezca el mismo no

# %%
# Muestra el tamaño de X, X_train, y_train, X_test e y_test
print("Total features shape:", X.shape)
print("Train features shape:", X_train.shape)
print("Train target shape:", y_train.shape)
print("Test features shape:", X_test.shape)
print("Test target shape:", y_test.shape)
# Out:
# Total features shape: (21, 1)
# Train features shape: (14, 1)
# Train target shape: (14, 1)
# Test features shape: (7, 1)
# Test target shape: (7, 1)

# %%
# Instancia y entrena un regresor lineal
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# imprime el intercepto y el coeficiente
print(lm.intercept_)
print(lm.coef_)# corta en 1.85
# Out:
# [1.85209063]
# [[-0.00414006]]

# %% [markdown]
# (Altura) = 1.85 - 0.0041*(Edad)

# %%
predictions = lm.predict(X-X_test) # prediccion con la x hria esto
predictions

# %%
# Realiza una predicción con el conjunto de test
coeff_df = pd.DataFrame(lm.coef_,
                        X.columns,
                        columns=['Coefficient'])
coeff_df
# Out:
#      Coefficient
# Age     -0.00414

# %% [markdown]
# *For every 1-year increase in Age, the predicted Height decreases by approximately 0.00414 meters (or 4.14 mm).*

# %%
# Crea un df con el conjunto de test
# df_test

X_test
# Out:
#     Age
# 0    24
# 17   34
# 15   32
# 1    25
# 8    36
# 5    27
# 11   30

# %%
# Añade una columna con la predicción
predicted_values = lm.predict(X_test)

X_test['Predicted_height'] = predicted_values

X_test
# Out:
#     Age  Predicted_height
# 0    24          1.752729
# 17   34          1.711329
# 15   32          1.719609
# 1    25          1.748589
# 8    36          1.703048
# 5    27          1.740309
# 11   30          1.727889

# %%
# Añade una columna con la altura real

X_test['Real_Height'] = df_alumnos.loc[X_test.index, 'Height']

X_test
# Out:
#     Age  Predicted_height  Real_Height
# 0    24          1.752729         1.82
# 17   34          1.711329         1.80
# 15   32          1.719609         1.75
# 1    25          1.748589         1.71
# 8    36          1.703048         1.74
# 5    27          1.740309         1.80
# 11   30          1.727889         1.65

# %%
# Crea un plot con los datos reales y la predicción
ages = X_test['Age']
real_heights = X_test['Real_Height']
predicted_heights = X_test['Predicted_height']

# Create the plot
plt.figure(figsize=(10, 6))
# Scatter plot for real height
plt.scatter(ages, real_heights, color='blue', label='Real Height', s=100)

# Line plot for predicted height
plt.plot(ages, predicted_heights, 'r--', label='Predicted Height', markersize=8)
# Add titles and labels
plt.title('Comparison of Predicted and Real Height', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Height (m)', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)

plt.show()

# %%
# Muestra el score del módelo

from sklearn import metrics

#lm.score(X_test, y_test)

model_score = lm.score(X_test[['Age']], y_test)#rl score es el R2
model_score
# Out:
# -0.19742015635643928

# %%
model_score = lm.score(X_train[['Age']], y_train)

# %%
# Out:
#     Edad  predict_height  real_height
# 0     24        1.752729         1.82
# 17    34        1.711329         1.80
# 15    32        1.719609         1.75
# 1     25        1.748589         1.71
# 8     36        1.703048         1.74
# 5     27        1.740309         1.80
# 11    30        1.727889         1.65

# %%
# from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

# %%
# Muestra el Mean Absolute Error, el Mean Squared Error y el Root Mean Squared Error

print('MAE:', metrics.mean_absolute_error(y_test, X_test['Predicted_height']))
print('MSE', metrics.mean_squared_error(y_test, X_test['Predicted_height']))
print('RMSE', metrics.root_mean_squared_error(y_test, X_test['Predicted_height']))
# Out:
# MAE: 0.05706488156539665
# MSE 0.0036851216240520687
# RMSE 0.060705202611078306

# %%
# Muestra el Mean Absolute Percentage Error

print('MAPE', metrics.mean_absolute_error(y_test, X_test['Predicted_height']))
# Out:
# MAPE 0.05706488156539665

# %%
# Muestra cual sería la predicción para 85 años de edad

rm.predict([[85]])#tiene q ser bidimiensional doble corchetes!
# Out:
# c:\Users\Rodrigo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.50018538])

# %%
# Ahora vamos a calcular el MAE, MSE, RMSE y MAPE a mano

# %%
# Añade una columna con el error
df_test["error"] = abs(df_test.real_)
# Out:
#     Edad  predict_height  real_height     error
# 0     24        1.752729         1.82  0.067271
# 17    34        1.711329         1.80  0.088671
# 15    32        1.719609         1.75  0.030391
# 1     25        1.748589         1.71  0.038589
# 8     36        1.703048         1.74  0.036952
# 5     27        1.740309         1.80  0.059691
# 11    30        1.727889         1.65  0.077889

# %%
# Muestra el error medio
# Out:
# 0.05706488156539665

# %%
# Añade una columna que contenga el error cuadrático
# Out:
#     Edad  predict_height  real_height     error  error_cuadratico
# 0     24        1.752729         1.82  0.067271          0.004525
# 17    34        1.711329         1.80  0.088671          0.007863
# 15    32        1.719609         1.75  0.030391          0.000924
# 1     25        1.748589         1.71  0.038589          0.001489
# 8     36        1.703048         1.74  0.036952          0.001365
# 5     27        1.740309         1.80  0.059691          0.003563
# 11    30        1.727889         1.65  0.077889          0.006067

# %%
# Muestra el error cuadrático medio
# Out:
# 0.0036851216240520687

# %%
# Muestra la raíz del error cuadrático medio
# Out:
# 0.060705202611078306

# %%
# Muestra el error absoluto medio porcentual
# Out:
# 0.032555352156298005
