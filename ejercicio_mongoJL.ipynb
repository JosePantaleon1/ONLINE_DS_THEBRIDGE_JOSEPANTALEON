# %%
# pip install pymongo

# %%
import pymongo
import json

# %%
# url = 'mongodb+srv://admin:admin@cluster0.xmr3d6s.mongodb.net/?retryWrites=true&w=majority'

# %%
url = "mongodb+srv://admin:admin@cluster0.jpwo6w9.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
with open('restaurants.json','r') as r:
    data = json.load(r)


# url = f'{connection_type}+{user}+':'+{password}+{adress}+{resto}'
myclient = pymongo.MongoClient(url)

mydb = myclient["Cluster0"] # INSTANCIAR BASE DE DATOS
restaurantes = mydb['restaurantes']
restaurantes.insert_many(data)
# Out:
# InsertManyResult([ObjectId('6734f92d8960e2ae3406c61a'), ObjectId('6734f92d8960e2ae3406c61b'), ObjectId('6734f92d8960e2ae3406c61c'), ObjectId('6734f92d8960e2ae3406c61d'), ObjectId('6734f92d8960e2ae3406c61e'), ObjectId('6734f92d8960e2ae3406c61f'), ObjectId('6734f92d8960e2ae3406c620'), ObjectId('6734f92d8960e2ae3406c621'), ObjectId('6734f92d8960e2ae3406c622'), ObjectId('6734f92d8960e2ae3406c623'), ObjectId('6734f92d8960e2ae3406c624'), ObjectId('6734f92d8960e2ae3406c625'), ObjectId('6734f92d8960e2ae3406c626'), ObjectId('6734f92d8960e2ae3406c627'), ObjectId('6734f92d8960e2ae3406c628'), ObjectId('6734f92d8960e2ae3406c629'), ObjectId('6734f92d8960e2ae3406c62a'), ObjectId('6734f92d8960e2ae3406c62b'), ObjectId('6734f92d8960e2ae3406c62c'), ObjectId('6734f92d8960e2ae3406c62d'), ObjectId('6734f92d8960e2ae3406c62e'), ObjectId('6734f92d8960e2ae3406c62f'), ObjectId('6734f92d8960e2ae3406c630'), ObjectId('6734f92d8960e2ae3406c631'), ObjectId('6734f92d8960e2ae3406c632'), ObjectId('6734f92d8960e2ae3406
# ...

# %%
# Mostrar todos los documentos de la colección restaurantes

filtro ={}
proyeccion = {"id" :0}
list(restaurantes.find(filtro,proyeccion))


filtro  = {}
proyeccion = {"id": 0}

list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'_id': ObjectId('67349b13ace753fad167f78b'),
#   'address': {'building': '1007',
#    'coord': [-73.856077, 40.848447],
#    'street': 'Morris Park Ave',
#    'zipcode': '10462'},
#   'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1378857600000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1358985600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1322006400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1299715200000}, 'grade': 'B', 'score': 14}],
#   'name': 'Morris Park Bake Shop',
#   'restaurant_id': '30075445'},
#  {'_id': ObjectId('67349b13ace753fad167f78c'),
#   'address': {'building': '469',
#    'coord': [-73.961704, 40.662942],
#    'street': 'Flatbush Avenue',
#    'zipcode': '11225'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1419897600000}, 'grade': 'A', 'score': 8},
# ...

# %%
filtro ={"cuisine": "bakery", "borough": "Bronx"}
proyeccion = {"id" :0}
list(restaurantes.find(filtro,proyeccion))


filtro = {"cuisine": "bakery", "borough": "Bronx"}

proyeccion = {"id" : 0}

list(restaurantes.find(filtro, proyeccion))
# Out:
# []

# %%
list
# Out:
# list

# %%
#Mostrar los campos restaurant_id, nombre, distrito y cocina, pero excluya el campo _id para todos los documentos de la colección restaurantes

list(restaurantes.find({'borough':'Bronx'},{'_id':0,'restaurant_id':1,'name':1,'borough':1,'cuisine':1}))

list(restaurantes.find
# Out:
# [{'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Morris Park Bake Shop',
#   'restaurant_id': '30075445'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Wild Asia',
#   'restaurant_id': '40357217'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363093'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden',
#   'restaurant_id': '40363289'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden',
#   'restaurant_id': '40364296'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Manhem Club',
#   'restaurant_id': '40364363'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The New Starling Athletic Club Of The Bronx',
#   'restaurant_id': '40364956'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Yankee Tavern',
#   'restaurant_id': '40365499'},
#  {'borough': 'Bronx',
# ...

# %%
# Mostrar los primeros 5 restaurantes que se encuentran en el distrito Bronx
list(restaurantes.find({'borough':'Bronx'},{'_id':0}).limit(5))
# Out:
# [{'address': {'building': '1007',
#    'coord': [-73.856077, 40.848447],
#    'street': 'Morris Park Ave',
#    'zipcode': '10462'},
#   'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1378857600000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1358985600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1322006400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1299715200000}, 'grade': 'B', 'score': 14}],
#   'name': 'Morris Park Bake Shop',
#   'restaurant_id': '30075445'},
#  {'address': {'building': '2300',
#    'coord': [-73.8786113, 40.8502883],
#    'street': 'Southern Boulevard',
#    'zipcode': '10460'},
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1401235200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1371600000000}, 'grade': 'A', 'score': 4},
# ...

# %%
#devolver los restaurantes que consiguieron una puntuacion mayor a 80 pero menor que 100
mydb = myclient["Cluster0"]
restaurantes = mydb['restaurantes']


query = {
    "grades.score": {
        "$gt": 80,
        "$lt": 100
    }
}

result = restaurantes.find(query, {"name": 1, "grades.score": 1})


for restaurant in result:
    print(restaurant)

    query = {}

query = {"grades.score":{$'gt': 80, $"lt":100}}

result = restaurantes.find(query, {"name":1, "grade.score":1})
# Out:
# {'_id': ObjectId('67349b13ace753fad167f8e9'), 'grades': [{'score': 11}, {'score': 131}, {'score': 11}, {'score': 25}, {'score': 11}, {'score': 13}], 'name': "Murals On 54/Randolphs'S"}
# {'_id': ObjectId('67349b13ace753fad167f98a'), 'grades': [{'score': 5}, {'score': 8}, {'score': 12}, {'score': 2}, {'score': 9}, {'score': 92}, {'score': 41}], 'name': 'Gandhi'}
# {'_id': ObjectId('67349b13ace753fad167faed'), 'grades': [{'score': 31}, {'score': 98}, {'score': 32}, {'score': 21}, {'score': 11}], 'name': 'Bella Napoli'}
# {'_id': ObjectId('67349b13ace753fad1680359'), 'grades': [{'score': 89}, {'score': 6}, {'score': 13}], 'name': 'West 79Th Street Boat Basin Cafe'}
# {'_id': ObjectId('67349befd233f49d077ea84f'), 'grades': [{'score': 11}, {'score': 131}, {'score': 11}, {'score': 25}, {'score': 11}, {'score': 13}], 'name': "Murals On 54/Randolphs'S"}
# ...

# %%
# Latitud menor a -95.754168
filtro = {
    "address.coord.0": {
        "$lt": -95.754168  
    }
}


proyeccion = {}


resultados = list(restaurantes.find(filtro, proyeccion))


for restaurante in resultados:
    print(restaurante)
# Out:
# {'_id': ObjectId('67349b13ace753fad167fdd3'), 'address': {'building': '3707', 'coord': [-101.8945214, 33.5197474], 'street': '82 Street', 'zipcode': '11372'}, 'borough': 'Queens', 'cuisine': 'American ', 'grades': [{'date': {'$date': 1401840000000}, 'grade': 'A', 'score': 12}, {'date': {'$date': 1383782400000}, 'grade': 'B', 'score': 19}, {'date': {'$date': 1368748800000}, 'grade': 'A', 'score': 11}, {'date': {'$date': 1346198400000}, 'grade': 'A', 'score': 11}, {'date': {'$date': 1333411200000}, 'grade': 'A', 'score': 12}, {'date': {'$date': 1321401600000}, 'grade': 'A', 'score': 7}], 'name': 'Burger King', 'restaurant_id': '40534067'}
# ...

# %%
# Devolver los restaurantes que no preparan cocina americana y lograron una calificación 'A' que no pertenece al distrito de Brooklyn.
mydb = myclient["Cluster0"]
restaurantes = mydb['restaurantes']

filtro = {
    "cuisine": {"$ne": "American "},
    "grades.grade": "A",
    "borough": {"$ne": "Brooklyn"}
}

proyeccion = {
    "_id": 0,
    "name": 1,
    "cuisine": 1,
    "borough": 1,
    "grades.grade": 1
}

resultados = list(restaurantes.find(filtro, proyeccion))


for restaurante in resultados:
    print(restaurante)
# Out:
# {'borough': 'Bronx', 'cuisine': 'Bakery', 'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'B'}], 'name': 'Morris Park Bake Shop'}
# {'borough': 'Manhattan', 'cuisine': 'Irish', 'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}], 'name': 'Dj Reynolds Pub And Restaurant'}
# {'borough': 'Queens', 'cuisine': 'Jewish/Kosher', 'grades': [{'grade': 'Z'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'B'}], 'name': 'Tov Kosher Kitchen'}
# {'borough': 'Staten Island', 'cuisine': 'Jewish/Kosher', 'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}], 'name': 'Kosher Island'}
# {'borough': 'Queens', 'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}], 'name': 'Carvel Ice Cream'}
# {'borough': 'Queens', 'cuisine': 'Delicatessen', 'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}], 'name': "Sal'S Deli"}
# ...

# %%
#Devolver los restaurantes que pertenecen al distrito Bronx y preparan platos americanos o chinos.
mydb = myclient["Cluster0"]
restaurantes = mydb['restaurantes']

filtro = {
    "borough": "Bronx",
    "cuisine": {"$in": ["American ", "Chinese"]}
}

proyeccion = {
    "_id": 0,
    "name": 1,
    "cuisine": 1,
    "borough": 1
}

resultados = list(restaurantes.find(filtro, proyeccion))


for restaurante in resultados:
    print(restaurante)
# Out:
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Wild Asia'}
# {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Happy Garden'}
# {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Happy Garden'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Manhem Club'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'The New Starling Athletic Club Of The Bronx'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Yankee Tavern'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'The Punch Bowl'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Munchtime'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Marina Delray'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Cool Zone'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Beaver Pond'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'African Market (Baboon Cafe)'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Blue Bay Restaurant'}
# ...

# %%
#Devolver el ID del restaurante, nombre, distrito y la cocina para aquellos restaurantes que pertenecen al distrito de Staten Island, Queens, Bronx o Brooklyn.
mydb = myclient["Cluster0"]
restaurantes = mydb['restaurantes']

filtro = {
    "borough": {"$in": ["Staten Island", "Queens", "Bronx", "Brooklyn"]}
}

proyeccion = {
    "_id": 0,
    "borough": 1,
    "cuisine": 1,
    "name": 1
}

resultados = list(restaurantes.find(filtro, proyeccion))


for restaurante in resultados:
    print(f"{restaurante}")
# Out:
# {'borough': 'Bronx', 'cuisine': 'Bakery', 'name': 'Morris Park Bake Shop'}
# {'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'name': "Wendy'S"}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Riviera Caterer'}
# {'borough': 'Queens', 'cuisine': 'Jewish/Kosher', 'name': 'Tov Kosher Kitchen'}
# {'borough': 'Queens', 'cuisine': 'American ', 'name': 'Brunos On The Boulevard'}
# {'borough': 'Staten Island', 'cuisine': 'Jewish/Kosher', 'name': 'Kosher Island'}
# {'borough': 'Brooklyn', 'cuisine': 'Delicatessen', 'name': "Wilken'S Fine Food"}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'Regina Caterers'}
# {'borough': 'Brooklyn', 'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Taste The Tropics Ice Cream'}
# {'borough': 'Bronx', 'cuisine': 'American ', 'name': 'Wild Asia'}
# {'borough': 'Brooklyn', 'cuisine': 'American ', 'name': 'C & C Catering Service'}
# {'borough': 'Brooklyn', 'cuisine': 'Chinese', 'name': 'May May Kitchen'}
# ...

# %%
Devolver el ID del restaurante, nombre y la cocina de aquellos restaurantes que lograron una puntuación que no supere los 10.
mydb = myclient["Cluster0"]
restaurantes = mydb['restaurantes']

filtro = {
    "grades.score": {"$lte": 10}
}

proyeccion = {
    "_id": 1,
    "name": 1,
    "cuisine": 1
}

resultados_puntuacion_baja = list(restaurantes.find(filtro, proyeccion))

for restaurante in resultados_puntuacion_baja:
    print(f"{restaurante}")
# Out:
# {'_id': ObjectId('67349b13ace753fad167f78b'), 'cuisine': 'Bakery', 'name': 'Morris Park Bake Shop'}
# {'_id': ObjectId('67349b13ace753fad167f78c'), 'cuisine': 'Hamburgers', 'name': "Wendy'S"}
# {'_id': ObjectId('67349b13ace753fad167f78d'), 'cuisine': 'Irish', 'name': 'Dj Reynolds Pub And Restaurant'}
# {'_id': ObjectId('67349b13ace753fad167f78e'), 'cuisine': 'American ', 'name': 'Riviera Caterer'}
# {'_id': ObjectId('67349b13ace753fad167f790'), 'cuisine': 'American ', 'name': 'Brunos On The Boulevard'}
# {'_id': ObjectId('67349b13ace753fad167f791'), 'cuisine': 'Jewish/Kosher', 'name': 'Kosher Island'}
# {'_id': ObjectId('67349b13ace753fad167f792'), 'cuisine': 'Delicatessen', 'name': "Wilken'S Fine Food"}
# {'_id': ObjectId('67349b13ace753fad167f793'), 'cuisine': 'American ', 'name': 'Regina Caterers'}
# {'_id': ObjectId('67349b13ace753fad167f794'), 'cuisine': 'Ice Cream, Gelato, Yogurt, Ices', 'name': 'Taste The Tropics Ice Cream'}
# ...

# %%
ydb = myclient["Cluster0"]
restaurantes = mydb['restaurantes']

filtro = {
    "grades": {
        "$elemMatch": {
            "grade": "A",
            "score": 11,
            "date": datetime(2014, 8, 11)
        }
    }
}

proyeccion = {
    "_id": 1,
    "name": 1,
    "grades": 1
}

resultados_calificacion_a = list(restaurantes.find(filtro, proyeccion))


for restaurante in resultados_calificacion_a:
    print(f"{restaurante}")
