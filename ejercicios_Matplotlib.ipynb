# %% [markdown]
# ## Ejercicios de Matplotlib

# %% [markdown]
# 1. Importa pyplot, numpy y pandas

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Activa matplotlib de forma estática

# %%
# %matplotlib inline

# %% [markdown]
# 3. Sabemos que podemos pintar gráficas de dos formas: la figura incluye los ejes o teniendo figura y ejes por separado.
#
# Usando solo una figura, usa numpy para los valores del eje X entre 0 y 5.
#
# Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5).
#
# Elige la precisión en el eje X que desees.

# %%
x = np.linspace(0, 5, 100)


y1 = 3 * x 
y2 = -3 * x - 5 
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.plot(x, y1, label='y = 3x', color='blue')
ax1.set_title('Recta con pendiente positiva')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.grid(True)  # Añadir una cuadrícula
ax1.legend()

ax2.plot(x, y2, label='y = -3x - 5', color='red')
ax2.set_title('Recta con pendiente negativa')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.grid(True)  # Añadir una cuadrícula
ax2.legend()

plt.tight_layout()

# %%
x = np.linspace(0, 5, 100)

# %% [markdown]
# 4. Fija el eje X entre 0 y 5 y el eje Y entre -15 y 15

# %%
x = np.linspace(0, 5, 100)

# Definir las rectas
y1 = 3 * x  # Recta con pendiente positiva que pasa por (0,0)
y2 = -3 * x - 5  # Recta con pendiente negativa que pasa por (0,-5)

# Crear una figura con dos subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Primera gráfica: Recta con pendiente positiva
ax1.plot(x, y1, label='y = 3x', color='blue')
ax1.set_title('Recta con pendiente positiva')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.grid(True)
ax1.legend()

# Fijar límites de los ejes
ax1.set_xlim(0, 5)  # Límite del eje X entre 0 y 5
ax1.set_ylim(-15, 15)  # Límite del eje Y entre -15 y
# Out:
# (-15.0, 15.0)

# %% [markdown]
# 5. Llama al eje X "eje X", al eje Y "eje Y" y pon de títulos "recta sube" y "recta baja". Muestra dos etiquetas de ejeX pero solo una de eje Y.

# %%
x = np.linspace(0, 5, 100)

# Definir las rectas
y1 = 3 * x  # Recta con pendiente positiva que pasa por (0,0)
y2 = -3 * x - 5  # Recta con pendiente negativa que pasa por (0,-5)

# Crear una figura con dos subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5), sharey=True)  # Compartir el eje Y

# Primera gráfica: Recta con pendiente positiva
ax1.plot(x, y1, label='y = 3x', color='blue')
ax1.set_title('recta sube')  # Título de la primera gráfica
ax1.set_xlabel('eje X')  # Etiqueta del eje X
ax1.set_ylabel('eje Y')  # Etiqueta del eje Y (solo en la primera gráfica)
ax1.grid(True)
ax1.legend()

# Fijar límites de los ejes
ax1.set_xlim(0, 5)
ax1.set_ylim(-15, 15)

# Segunda gráfica: Recta con pendiente negativa
ax2.plot(x, y2, label='y = -3x - 5', color='red')
ax2.set_title('recta baja')  # Título de la segunda gráfica
ax2.set_xlabel('eje X')  # Etiqueta del eje X
ax2.grid(True)
ax2.legend()

# Fijar límites de los ejes
ax2.set_xlim(0, 5)

# Ajustar el espacio entre los subplots
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# Vamos a pintar lo mismo pero accediendo directamente a los ejes

# %% [markdown]
# 6. Usando una figura Y EJES POR SEPARADO, usa numpy para los valores del eje X entre 0 y 5. Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5). Elige la precisión en el eje X que desees.

# %%
y1 = 3 * x  # Recta con pendiente positiva que pasa por (0,0)
y2 = -3 * x - 5  # Recta con pendiente negativa que pasa por (0,-5)

# Crear la figura
fig = plt.figure(figsize=(10, 5))

# Añadir el primer eje (a la izquierda) con su posición
ax1 = fig.add_axes([0.1, 0.1, 0.35, 0.8])  # [izquierda, abajo, ancho, alto]
ax1.plot(x, y1, label='y = 3x', color='blue')
ax1.set_title('Recta con pendiente positiva')
ax1.set_xlabel('eje X')
ax1.set_ylabel('eje Y')
ax1.grid(True)
ax1.legend()

# Añadir el segundo eje (a la derecha) con su posición
ax2 = fig.add_axes([0.55, 0.1, 0.35, 0.8])  # [izquierda, abajo, ancho, alto]
ax2.plot(x, y2, label='y = -3x - 5', color='red')
ax2.set_title('Recta con pendiente negativa')
ax2.set_xlabel('eje X')
ax2.grid(True)
ax2.legend()

# Mostrar la figura con las dos gráficas
plt.show()

# %% [markdown]
# 7. Crea una lista de coordenadas X: 20, 22, 24, 26, 28
# Crea una lista de coordenadas Y: 5, 15, -5, 20, 5
# Usa un gráfico de barras colocadas en X con alturas Y

# %%
# Lista de coordenadas X y Y
x = [20, 22, 24, 26, 28]
y = [5, 15, -5, 20, 5]

# Crear el gráfico de barras
plt.bar(x, y, color='blue')

# Añadir etiquetas y título
plt.xlabel('Coordenadas X')
plt.ylabel('Alturas Y')
plt.title('Gráfico de barras')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# 8. Crea un gráfico de barras. Pintamos la altura de un grupo de amigos, cada barra representa a una persona. Ana mide 160 cm, Luis mide 180 cm, Pedro mide 175 cm, Sofía mide 190 cm, Carmen mide 170 cm. Las barras serán verdes.
# Consejo: si no vas a tener que manipular especialmente los ejes, es más sencillo dejarlos dentro de la figura.

# %%
personas = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Crear el gráfico de barras
plt.bar(personas, alturas, color='green')

# Añadir etiquetas y título
plt.xlabel('Personas')
plt.ylabel('Altura (cm)')
plt.title('Altura de un grupo de amigos')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# 9. Basándote en el gráfico anterior, escribe encima de cada barra la altura de cada amigo.
# Pista: usa un bucle que lea cada barra de barplot = plt.bar(x,y)
# bar tiene los métodos get_height(), get_x(), get_width()
# plt.text(x,y,valor, va='bottom')

# %%
personas = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Crear el gráfico de barras
barplot = plt.bar(personas, alturas, color='green')

# Añadir etiquetas y título
plt.xlabel('Personas')
plt.ylabel('Altura (cm)')
plt.title('Altura de un grupo de amigos')

# Añadir la altura encima de cada barra
for bar in barplot:
    height = bar.get_height()  # Obtener la altura de la barra
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{int(height)}', 
             ha='center', va='bottom')  # Escribir el valor encima de la barra

# Mostrar la gráfica
plt.show()

# %% [markdown]
# 10. Cambia el tamaño de la figura a (3,5)

# %%
personas = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Crear la figura con el tamaño deseado
plt.figure(figsize=(3, 5))

# Crear el gráfico de barras
barplot = plt.bar(personas, alturas, color='green')

# Añadir etiquetas y título
plt.xlabel('Personas')
plt.ylabel('Altura (cm)')
plt.title('Altura de un grupo de amigos')

# Añadir la altura encima de cada barra
for bar in barplot:
    height = bar.get_height()  # Obtener la altura de la barra
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{int(height)}', 
             ha='center', va='bottom')  # Escribir el valor encima de la barra

# Mostrar la gráfica
plt.show()

# %% [markdown]
# 11. Basándote en el gráfico anterior, borra la escala del eje Y (ya aparece en la altura)
# Pista: cuando plt.yticks() recibe una lista vacía no pinta el eje Y

# %%
# Nombres de las personas y sus alturas
personas = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Crear la figura con el tamaño deseado
plt.figure(figsize=(3, 5))

# Crear el gráfico de barras
barplot = plt.bar(personas, alturas, color='green')

# Añadir etiquetas y título
plt.xlabel('Personas')
plt.ylabel('Altura (cm)')
plt.title('Altura de un grupo de amigos')

# Añadir la altura encima de cada barra
for bar in barplot:
    height = bar.get_height()  # Obtener la altura de la barra
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{int(height)}', 
             ha='center', va='bottom')  # Escribir el valor encima de la barra

# Eliminar la escala del eje Y
plt.yticks([])  # No mostrar ninguna etiqueta en el eje Y

# Mostrar la gráfica
plt.show()

# %% [markdown]
# 12. Prueba a hacer el gráfico con las barras en horizontal (no es necesario poner el texto al final de la barra).

# %%
import matplotlib.pyplot as plt

# Nombres de las personas y sus alturas
personas = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Crear la figura con el tamaño deseado
plt.figure(figsize=(5, 3))  # Cambié a (5, 3) para que se adapte mejor a barras horizontales

# Crear el gráfico de barras horizontales
plt.barh(personas, alturas, color='green')

# Añadir etiquetas y título
plt.xlabel('Altura (cm)')
plt.ylabel('Personas')
plt.title('Altura de un grupo de amigos')

# Eliminar la escala del eje Y
plt.xticks([])  # No mostrar ninguna etiqueta en el eje X si no es necesario

# Mostrar la gráfica
plt.show()
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# 13. Prueba a invertir los ejes con ax.invert_axis()
# Necesitarás tener los ejes disponibles fuera de la figura

# %%
import matplotlib.pyplot as plt

# Nombres de las personas y sus alturas
personas = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(5, 3))  # Tamaño de la figura

# Crear el gráfico de barras horizontales
ax.barh(personas, alturas, color='green')

# Añadir etiquetas y título
ax.set_xlabel('Altura (cm)')
ax.set_ylabel('Personas')
ax.set_title('Altura de un grupo de amigos')

# Invertir los ejes
ax.invert_yaxis()  # Invertir el eje Y

# Mostrar la gráfica
plt.show()

# %% [markdown]
# 14. En el último gráfico, cambia el estilo a 'dark_background'

# %%
# Cambiar el estilo a 'dark_background'
plt.style.use('dark_background')

# Nombres de las personas y sus alturas
personas = ['Ana', 'Luis', 'Pedro', 'Sofía', 'Carmen']
alturas = [160, 180, 175, 190, 170]

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(5, 3))  # Tamaño de la figura

# Crear el gráfico de barras horizontales
ax.barh(personas, alturas, color='green')

# Añadir etiquetas y título
ax.set_xlabel('Altura (cm)')
ax.set_ylabel('Personas')
ax.set_title('Altura de un grupo de amigos')

# Invertir los ejes
ax.invert_yaxis()  # Invertir el eje Y

# Mostrar la gráfica
plt.show()

# %%
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# 15. Vamos a introducir pandas. Crea un DataFrame con las columnas "Year" de valores 2015, 2016, 2017, 2018, 2019 y la columna "Sold_items_A" de valores 1000, 3500, 4000, 5500, 7000

# %%
# Crear el DataFrame
data = {
    'Year': [2015, 2016, 2017, 2018, 2019],
    'Sold_items_A': [1000, 3500, 4000, 5500, 7000]
}

df = pd.DataFrame(data)

# Cambiar el estilo a 'dark_background'
plt.style.use('dark_background')

# Crear el gráfico
plt.figure(figsize=(8, 4))
plt.plot(df['Year'], df['Sold_items_A'], marker='o', color='green', linestyle='-')

# Añadir etiquetas y título
plt.xlabel('Year')
plt.ylabel('Sold Items A')
plt.title('Items Sold Over Years')

# Mostrar la gráfica
plt.grid()
plt.show()

# %%
# Out:
# year            int64
# sold_items_A    int64
# dtype: object

# %% [markdown]
# 16. Ahora pintamos un gráfico de línea con las ventas respecto al año. Pon un título y etiquetas en los ejes.
# Cambia el estilo a 'seaborn-white'. La línea debe ser con rayas y verde.

# %%
# Crear el DataFrame
data = {
    'Year': [2015, 2016, 2017, 2018, 2019],
    'Sold_items_A': [1000, 3500, 4000, 5500, 7000]
}

df = pd.DataFrame(data)

# Cambiar el estilo a 'seaborn-white'


# Crear el gráfico de línea
plt.figure(figsize=(8, 4))
plt.plot(df['Year'], df['Sold_items_A'], linestyle='--', color='green', marker='o')  # Línea con rayas

# Añadir etiquetas y título
plt.xlabel('Year')
plt.ylabel('Sold Items A')
plt.title('Items Sold Over Years')
# Out:
# Text(0.5, 1.0, 'Items Sold Over Years')

# %% [markdown]
# 17. Otro departamento B ha vendido en esos años 2000, 3100, 5000, 4000, 6000 unidades. Incluye esa columna en el DataFrame y pinta en la misma gráfica las dos líneas. B es una línea punteada y roja. Muestra una leyenda abajo a la derecha.

# %%
data = {
    'Year': [2015, 2016, 2017, 2018, 2019],
    'Sold_items_A': [1000, 3500, 4000, 5500, 7000],
    'Sold_items_B': [2000, 3100, 5000, 4000, 6000]
}

df = pd.DataFrame(data)


# Crear el gráfico de línea
plt.figure(figsize=(8, 4))
plt.plot(df['Year'], df['Sold_items_A'], linestyle='--', color='green', marker='o', label='Department A')  # Línea con rayas para A
plt.plot(df['Year'], df['Sold_items_B'], linestyle=':', color='red', marker='x', label='Department B')  # Línea punteada para B

# Añadir etiquetas y título
plt.xlabel('Year')
plt.ylabel('Sold Items')
plt.title('Items Sold Over Years')

# Añadir leyenda
plt.legend(loc='lower right')

# Mostrar la gráfica
plt.grid()
plt.show()

# %% [markdown]
# 18. Haz un scatter del departamento A usando __solo el DataFrame__.
# Pista: el propio DataFrame tiene un método plot.
# df.plot('columna X', 'columna Y', 'kind' = 'scatter)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear el DataFrame con las ventas de ambos departamentos
data = {
    'Year': [2015, 2016, 2017, 2018, 2019],
    'Sold_items_A': [1000, 3500, 4000, 5500, 7000],
    'Sold_items_B': [2000, 3100, 5000, 4000, 6000]
}

df = pd.DataFrame(data)

# Crear el gráfico de dispersión para el departamento A
df.plot(x='Year', y='Sold_items_A', kind='scatter', color='green', marker='o', figsize=(8, 4))

# Añadir etiquetas y título
plt.xlabel('Year')
plt.ylabel('Sold Items A')
plt.title('Scatter Plot of Sold Items A Over Years')

# Mostrar la gráfica
plt.grid()
plt.show()

# %% [markdown]
# 19. Prueba a cambiar kind a 'pie'

# %%
data = {
    'Year': [2015, 2016, 2017, 2018, 2019],
    'Sold_items_A': [1000, 3500, 4000, 5500, 7000],
    'Sold_items_B': [2000, 3100, 5000, 4000, 6000]
}

df = pd.DataFrame(data)



# Crear el gráfico de pastel para el departamento A
plt.figure(figsize=(8, 4))
df['Sold_items_A'].plot(kind='pie', labels=df['Year'], autopct='%1.1f%%', startangle=90)

# Añadir título
plt.title('Proporción de Sold Items A por Año')

# Mostrar la gráfica
plt.ylabel('')  # Eliminar la etiqueta del eje Y, ya que no es necesaria en un gráfico de pastel
plt.show()

# %% [markdown]
# 20. Prueba a quitar la leyenda incluyendo legend igual a False, añade labels y quita la etiqueta en Y

# %%
data = {
    'Year': [2015, 2016, 2017, 2018, 2019],
    'Sold_items_A': [1000, 3500, 4000, 5500, 7000],
    'Sold_items_B': [2000, 3100, 5000, 4000, 6000]
}

df = pd.DataFrame(data)


# Crear el gráfico de pastel para el departamento A
plt.figure(figsize=(8, 4))
df['Sold_items_A'].plot(kind='pie', labels=df['Year'], autopct='%1.1f%%', startangle=90, legend=False)

# Añadir título
plt.title('Proporción de Sold Items A por Año')

# Eliminar la etiqueta del eje Y
plt.ylabel('')  

# Mostrar la gráfica
plt.show()

# %% [markdown]
# 21. Vamos a pintar un histograma

# %%
# Fijar una semilla para la reproducibilidad
np.random.seed(0)

# Generar una lista aleatoria de alturas (en cm) para 300 personas
# Suponiendo que la altura sigue una distribución normal
# Media de 170 cm y desviación estándar de 10 cm
num_personas = 300
altura_media = 170
desviacion_estandar = 10

alturas = np.random.normal(loc=altura_media, scale=desviacion_estandar, size=num_personas)

# Crear el histograma
plt.figure(figsize=(10, 6))
plt.hist(alturas, bins=30, color='blue', alpha=0.7, edgecolor='black')

# Añadir etiquetas y título
plt.xlabel('Altura (cm)')
plt.ylabel('Número de Personas')
plt.title('Histograma de Alturas de 300 Personas')

# Mostrar la cuadrícula
plt.grid(axis='y', alpha=0.75)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# Pista: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html
